# %%
# get a list of sp500 companies and their sector
# from wikipedia

import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

# get the list of sp500 companies and their sector

url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
table = soup.find('table', {'class': 'wikitable sortable'})
rows = table.find_all('tr')
sp500 = []
for row in rows[1:]:
    cols = row.find_all('td')
    sp500.append([cols[0].text.strip(), cols[2].text.strip(), cols[6].text.strip()])

# %%
#show the table
print(sp500)
#make a dataframe
df = pd.DataFrame(sp500, columns=['Symbol', 'Sector', 'CIK'])
sp500
# Out:
# [['MMM', 'Industrials', '0000066740'], ['AOS', 'Industrials', '0000091142'], ['ABT', 'Health Care', '0000001800'], ['ABBV', 'Health Care', '0001551152'], ['ACN', 'Information Technology', '0001467373'], ['ADBE', 'Information Technology', '0000796343'], ['AMD', 'Information Technology', '0000002488'], ['AES', 'Utilities', '0000874761'], ['AFL', 'Financials', '0000004977'], ['A', 'Health Care', '0001090872'], ['APD', 'Materials', '0000002969'], ['ABNB', 'Consumer Discretionary', '0001559720'], ['AKAM', 'Information Technology', '0001086222'], ['ALB', 'Materials', '0000915913'], ['ARE', 'Real Estate', '0001035443'], ['ALGN', 'Health Care', '0001097149'], ['ALLE', 'Industrials', '0001579241'], ['LNT', 'Utilities', '0000352541'], ['ALL', 'Financials', '0000899051'], ['GOOGL', 'Communication Services', '0001652044'], ['GOOG', 'Communication Services', '0001652044'], ['MO', 'Consumer Staples', '0000764180'], ['AMZN', 'Consumer Discretionary', '0001018724'], ['AMCR', 'Materials', '0001748790'], ['AEE', 'Utilities', '0001002910'], ['AAL', 'Industrials', '0000006201'], ['AEP', 'Utilities', '0000004904'], ['AXP', 'Financials', '0000004962'], ['AIG', 'Financials', '0000005272'], ['AMT', 'Real Estate', '0001053507'], ['AWK', 'Utilities', '0001410636'], ['AMP', 'Financials', '0000820027'], ['AME', 'Industrials', '0001037868'], ['AMGN', 'Health Care', '0000318154'], ['APH', 'Information Technology', '0000820313'], ['ADI', 'Information Technology', '0000006281'], ['ANSS', 'Information Technology', '0001013462'], ['AON', 'Financials', '0000315293'], ['APA', 'Energy', '0001841666'], ['AAPL', 'Information Technology', '0000320193'], ['AMAT', 'Information Technology', '0000006951'], ['APTV', 'Consumer Discretionary', '0001521332'], ['ACGL', 'Financials', '0000947484'], ['ADM', 'Consumer Staples', '0000007084'], ['ANET', 'Information Technology', '0001596532'], ['AJG', 'Financials', '0000354190'], ['AIZ', 'Financials', '0001267238'], ['T', 'Communication Services', '0000732717'], ['ATO', 'Utilities', '0000731802'], ['ADSK', 'Information Technology', '0000769397'], ['ADP', 'Industrials', '0000008670'], ['AZO', 'Consumer Discretionary', '0000866787'], ['AVB', 'Real Estate', '0000915912'], ['AVY', 'Materials', '0000008818'], ['AXON', 'Industrials', '0001069183'], ['BKR', 'Energy', '0001701605'], ['BALL', 'Materials', '0000009389'], ['BAC', 'Financials', '0000070858'], ['BK', 'Financials', '0001390777'], ['BBWI', 'Consumer Discretionary', '0000701985'], ['BAX', 'Health Care', '0000010456'], ['BDX', 'Health Care', '0000010795'], ['BRK.B', 'Financials', '0001067983'], ['BBY', 'Consumer Discretionary', '0000764478'], ['BIO', 'Health Care', '0000012208'], ['TECH', 'Health Care', '0000842023'], ['BIIB', 'Health Care', '0000875045'], ['BLK', 'Financials', '0001364742'], ['BX', 'Financials', '0001393818'], ['BA', 'Industrials', '0000012927'], ['BKNG', 'Consumer Discretionary', '0001075531'], ['BWA', 'Consumer Discretionary', '0000908255'], ['BXP', 'Real Estate', '0001037540'], ['BSX', 'Health Care', '0000885725'], ['BMY', 'Health Care', '0000014272'], ['AVGO', 'Information Technology', '0001730168'], ['BR', 'Industrials', '0001383312'], ['BRO', 'Financials', '0000079282'], ['BF.B', 'Consumer Staples', '0000014693'], ['BLDR', 'Industrials', '0001316835'], ['BG', 'Consumer Staples', '0001996862'], ['CDNS', 'Information Technology', '0000813672'], ['CZR', 'Consumer Discretionary', '0001590895'], ['CPT', 'Real Estate', '0000906345'], ['CPB', 'Consumer Staples', '0000016732'], ['COF', 'Financials', '0000927628'], ['CAH', 'Health Care', '0000721371'], ['KMX', 'Consumer Discretionary', '0001170010'], ['CCL', 'Consumer Discretionary', '0000815097'], ['CARR', 'Industrials', '0001783180'], ['CTLT', 'Health Care', '0001596783'], ['CAT', 'Industrials', '0000018230'], ['CBOE', 'Financials', '0001374310'], ['CBRE', 'Real Estate', '0001138118'], ['CDW', 'Information Technology', '0001402057'], ['CE', 'Materials', '0001306830'], ['COR', 'Health Care', '0001140859'], ['CNC', ...
# [['MMM', 'Industrials', '0000066740'],
#  ['AOS', 'Industrials', '0000091142'],
#  ['ABT', 'Health Care', '0000001800'],
#  ['ABBV', 'Health Care', '0001551152'],
#  ['ACN', 'Information Technology', '0001467373'],
#  ['ADBE', 'Information Technology', '0000796343'],
#  ['AMD', 'Information Technology', '0000002488'],
#  ['AES', 'Utilities', '0000874761'],
#  ['AFL', 'Financials', '0000004977'],
#  ['A', 'Health Care', '0001090872'],
#  ['APD', 'Materials', '0000002969'],
#  ['ABNB', 'Consumer Discretionary', '0001559720'],
#  ['AKAM', 'Information Technology', '0001086222'],
#  ['ALB', 'Materials', '0000915913'],
#  ['ARE', 'Real Estate', '0001035443'],
#  ['ALGN', 'Health Care', '0001097149'],
#  ['ALLE', 'Industrials', '0001579241'],
#  ['LNT', 'Utilities', '0000352541'],
#  ['ALL', 'Financials', '0000899051'],
#  ['GOOGL', 'Communication Services', '0001652044'],
#  ['GOOG', 'Communication Services', '0001652044'],
#  ['MO', 'Consumer Staples', '0000764180'],
#  ['AMZN', 'Consumer Discretionary', '0001018724'],
#  ['AMCR', 'Materials', '0001748790'],
#  ['AEE', 'Utilities', '0001002910'],
#  ['AAL', 'Industrials', '0000006201'],
#  ['AEP', 'Utilities', '0000004904'],
#  ['AXP', 'Financials', '0000004962'],
#  ['AIG', 'Financials', '0000005272'],
#  ['AMT', 'Real Estate', '0001053507'],
#  ['AWK', 'Utilities', '0001410636'],
#  ['AMP', 'Financials', '0000820027'],
#  ['AME', 'Industrials', '0001037868'],
#  ['AMGN', 'Health Care', '0000318154'],
#  ['APH', 'Information Technology', '0000820313'],
#  ['ADI', 'Information Technology', '0000006281'],
#  ['ANSS', 'Information Technology', '0001013462'],
#  ['AON', 'Financials', '0000315293'],
#  ['APA', 'Energy', '0001841666'],
#  ['AAPL', 'Information Technology', '0000320193'],
#  ['AMAT', 'Information Technology', '0000006951'],
#  ['APTV', 'Consumer Discretionary', '0001521332'],
#  ['ACGL', 'Financials', '0000947484'],
#  ['ADM', 'Consumer Staples', '0000007084'],
#  ['ANET', 'Information Technology', '0001596532'],
#  ['AJG', 'Financials', '0000354190'],
#  ['AIZ', 'Financials', '0001267238'],
#  ['T', 'Communication Services', '0000732717'],
#  ['ATO', 'Utilities', '0000731802'],
#  ['ADSK', 'Information Technology', '0000769397'],
#  ['ADP', 'Industrials', '0000008670'],
#  ['AZO', 'Consumer Discretionary', '0000866787'],
#  ['AVB', 'Real Estate', '0000915912'],
#  ['AVY', 'Materials', '0000008818'],
#  ['AXON', 'Industrials', '0001069183'],
#  ['BKR', 'Energy', '0001701605'],
#  ['BALL', 'Materials', '0000009389'],
#  ['BAC', 'Financials', '0000070858'],
#  ['BK', 'Financials', '0001390777'],
#  ['BBWI', 'Consumer Discretionary', '0000701985'],
#  ['BAX', 'Health Care', '0000010456'],
#  ['BDX', 'Health Care', '0000010795'],
#  ['BRK.B', 'Financials', '0001067983'],
#  ['BBY', 'Consumer Discretionary', '0000764478'],
#  ['BIO', 'Health Care', '0000012208'],
#  ['TECH', 'Health Care', '0000842023'],
#  ['BIIB', 'Health Care', '0000875045'],
#  ['BLK', 'Financials', '0001364742'],
#  ['BX', 'Financials', '0001393818'],
#  ['BA', 'Industrials', '0000012927'],
#  ['BKNG', 'Consumer Discretionary', '0001075531'],
#  ['BWA', 'Consumer Discretionary', '0000908255'],
#  ['BXP', 'Real Estate', '0001037540'],
#  ['BSX', 'Health Care', '0000885725'],
#  ['BMY', 'Health Care', '0000014272'],
#  ['AVGO', 'Information Technology', '0001730168'],
#  ['BR', 'Industrials', '0001383312'],
#  ['BRO', 'Financials', '0000079282'],
#  ['BF.B', 'Consumer Staples', '0000014693'],
#  ['BLDR', 'Industrials', '0001316835'],
#  ['BG', 'Consumer Staples', '0001996862'],
#  ['CDNS', 'Information Technology', '0000813672'],
#  ['CZR', 'Consumer Discretionary', '0001590895'],
#  ['CPT', 'Real Estate', '0000906345'],
#  ['CPB', 'Consumer Staples', '0000016732'],
#  ['COF', 'Financials', '0000927628'],
#  ['CAH', 'Health Care', '0000721371'],
#  ['KMX', 'Consumer Discretionary', '0001170010'],
#  ['CCL', 'Consumer Discretionary', '0000815097'],
#  ['CARR', 'Industrials', '0001783180'],
#  ['CTLT', 'Health Care', '0001596783'],
#  ['CAT', 'Industrials', '0000018230'],
#  ['CBOE', 'Financials', '0001374310'],
#  ['CBRE', 'Real Estate', '0001138118'],
#  ['CDW', 'Information Technology', '0001402057'],
#  ['CE', 'Materials', '0001306830'],
#  ['COR', 'Health Care', '0001140859'],
#  ['CNC', 'Health Care', '0001071739'],
#  ['CNP', 'Utilities', '0001130310'],
#  ['CDAY', 'Industrials', '0001725057'],
#  ['CF', 'Materials', '0001324404'],
#  ['CHRW', 'Industrials', '0001043277'],
#  ['CRL', 'Health Care', '0001100682'],
#  ['SCHW', 'Financials', '0000316709'],
#  ['CHTR', 'Communication Services', '0001091667'],
#  ['CVX', 'Energy', '0000093410'],
#  ['CMG', 'Consumer Discretionary', '0001058090'],
#  ['CB', 'Financials', '0000896159'],
#  ['CHD', 'Consumer Staples', '0000313927'],
#  ['CI', 'Health Care', '0001739940'],
#  ['CINF', 'Financials', '0000020286'],
#  ['CTAS', 'Industrials', '0000723254'],
#  ['CSCO', 'Information Technology', '0000858877'],
#  ['C', 'Financials', '0000831001'],
#  ['CFG', 'Financials', '0000759944'],
#  ['CLX', 'Consumer Staples', '0000021076'],
#  ['CME', 'Financials', '0001156375'],
#  ['CMS', 'Utilities', '0000811156'],
#  ['KO', 'Consumer Staples', '0000021344'],
#  ['CTSH', 'Information Technology', '0001058290'],
#  ['CL', 'Consumer Staples', '0000021665'],
#  ['CMCSA', 'Communication Services', '0001166691'],
#  ['CMA', 'Financials', '0000028412'],
#  ['CAG', 'Consumer Staples', '0000023217'],
#  ['COP', 'Energy', '0001163165'],
#  ['ED', 'Utilities', '0001047862'],
#  ['STZ', 'Consumer Staples', '0000016918'],
#  ['CEG', 'Utilities', '0001868275'],
#  ['COO', 'Health Care', '0000711404'],
#  ['CPRT', 'Industrials', '0000900075'],
#  ['GLW', 'Information Technology', '0000024741'],
#  ['CTVA', 'Materials', '0001755672'],
#  ['CSGP', 'Real Estate', '0001057352'],
#  ['COST', 'Consumer Staples', '0000909832'],
#  ['CTRA', 'Energy', '0000858470'],
#  ['CCI', 'Real Estate', '0001051470'],
#  ['CSX', 'Industrials', '0000277948'],
#  ['CMI', 'Industrials', '0000026172'],
#  ['CVS', 'Health Care', '0000064803'],
#  ['DHR', 'Health Care', '0000313616'],
#  ['DRI', 'Consumer Discretionary', '0000940944'],
#  ['DVA', 'Health Care', '0000927066'],
#  ['DE', 'Industrials', '0000315189'],
#  ['DAL', 'Industrials', '0000027904'],
#  ['XRAY', 'Health Care', '0000818479'],
#  ['DVN', 'Energy', '0001090012'],
#  ['DXCM', 'Health Care', '0001093557'],
#  ['FANG', 'Energy', '0001539838'],
#  ['DLR', 'Real Estate', '0001297996'],
#  ['DFS', 'Financials', '0001393612'],
#  ['DG', 'Consumer Staples', '0000029534'],
#  ['DLTR', 'Consumer Staples', '0000935703'],
#  ['D', 'Utilities', '0000715957'],
#  ['DPZ', 'Consumer Discretionary', '0001286681'],
#  ['DOV', 'Industrials', '0000029905'],
#  ['DOW', 'Materials', '0001751788'],
#  ['DHI', 'Consumer Discretionary', '0000882184'],
#  ['DTE', 'Utilities', '0000936340'],
#  ['DUK', 'Utilities', '0001326160'],
#  ['DD', 'Materials', '0001666700'],
#  ['EMN', 'Materials', '0000915389'],
#  ['ETN', 'Industrials', '0001551182'],
#  ['EBAY', 'Consumer Discretionary', '0001065088'],
#  ['ECL', 'Materials', '0000031462'],
#  ['EIX', 'Utilities', '0000827052'],
#  ['EW', 'Health Care', '0001099800'],
#  ['EA', 'Communication Services', '0000712515'],
#  ['ELV', 'Health Care', '0001156039'],
#  ['LLY', 'Health Care', '0000059478'],
#  ['EMR', 'Industrials', '0000032604'],
#  ['ENPH', 'Information Technology', '0001463101'],
#  ['ETR', 'Utilities', '0000065984'],
#  ['EOG', 'Energy', '0000821189'],
#  ['EPAM', 'Information Technology', '0001352010'],
#  ['EQT', 'Energy', '0000033213'],
#  ['EFX', 'Industrials', '0000033185'],
#  ['EQIX', 'Real Estate', '0001101239'],
#  ['EQR', 'Real Estate', '0000906107'],
#  ['ESS', 'Real Estate', '0000920522'],
#  ['EL', 'Consumer Staples', '0001001250'],
#  ['ETSY', 'Consumer Discretionary', '0001370637'],
#  ['EG', 'Financials', '0001095073'],
#  ['EVRG', 'Utilities', '0001711269'],
#  ['ES', 'Utilities', '0000072741'],
#  ['EXC', 'Utilities', '0001109357'],
#  ['EXPE', 'Consumer Discretionary', '0001324424'],
#  ['EXPD', 'Industrials', '0000746515'],
#  ['EXR', 'Real Estate', '0001289490'],
#  ['XOM', 'Energy', '0000034088'],
#  ['FFIV', 'Information Technology', '0001048695'],
#  ['FDS', 'Financials', '0001013237'],
#  ['FICO', 'Information Technology', '0000814547'],
#  ['FAST', 'Industrials', '0000815556'],
#  ['FRT', 'Real Estate', '0000034903'],
#  ['FDX', 'Industrials', '0001048911'],
#  ['FIS', 'Financials', '0001136893'],
#  ['FITB', 'Financials', '0000035527'],
#  ['FSLR', 'Information Technology', '0001274494'],
#  ['FE', 'Utilities', '0001031296'],
#  ['FI', 'Financials', '0000798354'],
#  ['FLT', 'Financials', '0001175454'],
#  ['FMC', 'Materials', '0000037785'],
#  ['F', 'Consumer Discretionary', '0000037996'],
#  ['FTNT', 'Information Technology', '0001262039'],
#  ['FTV', 'Industrials', '0001659166'],
#  ['FOXA', 'Communication Services', '0001754301'],
#  ['FOX', 'Communication Services', '0001754301'],
#  ['BEN', 'Financials', '0000038777'],
#  ['FCX', 'Materials', '0000831259'],
#  ['GRMN', 'Consumer Discretionary', '0001121788'],
#  ['IT', 'Information Technology', '0000749251'],
#  ['GEHC', 'Health Care', '0001932393'],
#  ['GEN', 'Information Technology', '0000849399'],
#  ['GNRC', 'Industrials', '0001474735'],
#  ['GD', 'Industrials', '0000040533'],
#  ['GE', 'Industrials', '0000040545'],
#  ['GIS', 'Consumer Staples', '0000040704'],
#  ['GM', 'Consumer Discretionary', '0001467858'],
#  ['GPC', 'Consumer Discretionary', '0000040987'],
#  ['GILD', 'Health Care', '0000882095'],
#  ['GPN', 'Financials', '0001123360'],
#  ['GL', 'Financials', '0000320335'],
#  ['GS', 'Financials', '0000886982'],
#  ['HAL', 'Energy', '0000045012'],
#  ['HIG', 'Financials', '0000874766'],
#  ['HAS', 'Consumer Discretionary', '0000046080'],
#  ['HCA', 'Health Care', '0000860730'],
#  ['PEAK', 'Real Estate', '0000765880'],
#  ['HSIC', 'Health Care', '0001000228'],
#  ['HSY', 'Consumer Staples', '0000047111'],
#  ['HES', 'Energy', '0000004447'],
#  ['HPE', 'Information Technology', '0001645590'],
#  ['HLT', 'Consumer Discretionary', '0001585689'],
#  ['HOLX', 'Health Care', '0000859737'],
#  ['HD', 'Consumer Discretionary', '0000354950'],
#  ['HON', 'Industrials', '0000773840'],
#  ['HRL', 'Consumer Staples', '0000048465'],
#  ['HST', 'Real Estate', '0001070750'],
#  ['HWM', 'Industrials', '0000004281'],
#  ['HPQ', 'Information Technology', '0000047217'],
#  ['HUBB', 'Industrials', '0000048898'],
#  ['HUM', 'Health Care', '0000049071'],
#  ['HBAN', 'Financials', '0000049196'],
#  ['HII', 'Industrials', '0001501585'],
#  ['IBM', 'Information Technology', '0000051143'],
#  ['IEX', 'Industrials', '0000832101'],
#  ['IDXX', 'Health Care', '0000874716'],
#  ['ITW', 'Industrials', '0000049826'],
#  ['ILMN', 'Health Care', '0001110803'],
#  ['INCY', 'Health Care', '0000879169'],
#  ['IR', 'Industrials', '0001699150'],
#  ['PODD', 'Health Care', '0001145197'],
#  ['INTC', 'Information Technology', '0000050863'],
#  ['ICE', 'Financials', '0001571949'],
#  ['IFF', 'Materials', '0000051253'],
#  ['IP', 'Materials', '0000051434'],
#  ['IPG', 'Communication Services', '0000051644'],
#  ['INTU', 'Information Technology', '0000896878'],
#  ['ISRG', 'Health Care', '0001035267'],
#  ['IVZ', 'Financials', '0000914208'],
#  ['INVH', 'Real Estate', '0001687229'],
#  ['IQV', 'Health Care', '0001478242'],
#  ['IRM', 'Real Estate', '0001020569'],
#  ['JBHT', 'Industrials', '0000728535'],
#  ['JBL', 'Information Technology', '0000898293'],
#  ['JKHY', 'Financials', '0000779152'],
#  ['J', 'Industrials', '0000052988'],
#  ['JNJ', 'Health Care', '0000200406'],
#  ['JCI', 'Industrials', '0000833444'],
#  ['JPM', 'Financials', '0000019617'],
#  ['JNPR', 'Information Technology', '0001043604'],
#  ['K', 'Consumer Staples', '0000055067'],
#  ['KVUE', 'Consumer Staples', '0001944048'],
#  ['KDP', 'Consumer Staples', '0001418135'],
#  ['KEY', 'Financials', '0000091576'],
#  ['KEYS', 'Information Technology', '0001601046'],
#  ['KMB', 'Consumer Staples', '0000055785'],
#  ['KIM', 'Real Estate', '0000879101'],
#  ['KMI', 'Energy', '0001506307'],
#  ['KLAC', 'Information Technology', '0000319201'],
#  ['KHC', 'Consumer Staples', '0001637459'],
#  ['KR', 'Consumer Staples', '0000056873'],
#  ['LHX', 'Industrials', '0000202058'],
#  ['LH', 'Health Care', '0000920148'],
#  ['LRCX', 'Information Technology', '0000707549'],
#  ['LW', 'Consumer Staples', '0001679273'],
#  ['LVS', 'Consumer Discretionary', '0001300514'],
#  ['LDOS', 'Industrials', '0001336920'],
#  ['LEN', 'Consumer Discretionary', '0000920760'],
#  ['LIN', 'Materials', '0001707925'],
#  ['LYV', 'Communication Services', '0001335258'],
#  ['LKQ', 'Consumer Discretionary', '0001065696'],
#  ['LMT', 'Industrials', '0000936468'],
#  ['L', 'Financials', '0000060086'],
#  ['LOW', 'Consumer Discretionary', '0000060667'],
#  ['LULU', 'Consumer Discretionary', '0001397187'],
#  ['LYB', 'Materials', '0001489393'],
#  ['MTB', 'Financials', '0000036270'],
#  ['MRO', 'Energy', '0000101778'],
#  ['MPC', 'Energy', '0001510295'],
#  ['MKTX', 'Financials', '0001278021'],
#  ['MAR', 'Consumer Discretionary', '0001048286'],
#  ['MMC', 'Financials', '0000062709'],
#  ['MLM', 'Materials', '0000916076'],
#  ['MAS', 'Industrials', '0000062996'],
#  ['MA', 'Financials', '0001141391'],
#  ['MTCH', 'Communication Services', '0000891103'],
#  ['MKC', 'Consumer Staples', '0000063754'],
#  ['MCD', 'Consumer Discretionary', '0000063908'],
#  ['MCK', 'Health Care', '0000927653'],
#  ['MDT', 'Health Care', '0001613103'],
#  ['MRK', 'Health Care', '0000310158'],
#  ['META', 'Communication Services', '0001326801'],
#  ['MET', 'Financials', '0001099219'],
#  ['MTD', 'Health Care', '0001037646'],
#  ['MGM', 'Consumer Discretionary', '0000789570'],
#  ['MCHP', 'Information Technology', '0000827054'],
#  ['MU', 'Information Technology', '0000723125'],
#  ['MSFT', 'Information Technology', '0000789019'],
#  ['MAA', 'Real Estate', '0000912595'],
#  ['MRNA', 'Health Care', '0001682852'],
#  ['MHK', 'Consumer Discretionary', '0000851968'],
#  ['MOH', 'Health Care', '0001179929'],
#  ['TAP', 'Consumer Staples', '0000024545'],
#  ['MDLZ', 'Consumer Staples', '0001103982'],
#  ['MPWR', 'Information Technology', '0001280452'],
#  ['MNST', 'Consumer Staples', '0000865752'],
#  ['MCO', 'Financials', '0001059556'],
#  ['MS', 'Financials', '0000895421'],
#  ['MOS', 'Materials', '0001285785'],
#  ['MSI', 'Information Technology', '0000068505'],
#  ['MSCI', 'Financials', '0001408198'],
#  ['NDAQ', 'Financials', '0001120193'],
#  ['NTAP', 'Information Technology', '0001002047'],
#  ['NFLX', 'Communication Services', '0001065280'],
#  ['NEM', 'Materials', '0001164727'],
#  ['NWSA', 'Communication Services', '0001564708'],
#  ['NWS', 'Communication Services', '0001564708'],
#  ['NEE', 'Utilities', '0000753308'],
#  ['NKE', 'Consumer Discretionary', '0000320187'],
#  ['NI', 'Utilities', '0001111711'],
#  ['NDSN', 'Industrials', '0000072331'],
#  ['NSC', 'Industrials', '0000702165'],
#  ['NTRS', 'Financials', '0000073124'],
#  ['NOC', 'Industrials', '0001133421'],
#  ['NCLH', 'Consumer Discretionary', '0001513761'],
#  ['NRG', 'Utilities', '0001013871'],
#  ['NUE', 'Materials', '0000073309'],
#  ['NVDA', 'Information Technology', '0001045810'],
#  ['NVR', 'Consumer Discretionary', '0000906163'],
#  ['NXPI', 'Information Technology', '0001413447'],
#  ['ORLY', 'Consumer Discretionary', '0000898173'],
#  ['OXY', 'Energy', '0000797468'],
#  ['ODFL', 'Industrials', '0000878927'],
#  ['OMC', 'Communication Services', '0000029989'],
#  ['ON', 'Information Technology', '0001097864'],
#  ['OKE', 'Energy', '0001039684'],
#  ['ORCL', 'Information Technology', '0001341439'],
#  ['OTIS', 'Industrials', '0001781335'],
#  ['PCAR', 'Industrials', '0000075362'],
#  ['PKG', 'Materials', '0000075677'],
#  ['PANW', 'Information Technology', '0001327567'],
#  ['PARA', 'Communication Services', '0000813828'],
#  ['PH', 'Industrials', '0000076334'],
#  ['PAYX', 'Industrials', '0000723531'],
#  ['PAYC', 'Industrials', '0001590955'],
#  ['PYPL', 'Financials', '0001633917'],
#  ['PNR', 'Industrials', '0000077360'],
#  ['PEP', 'Consumer Staples', '0000077476'],
#  ['PFE', 'Health Care', '0000078003'],
#  ['PCG', 'Utilities', '0001004980'],
#  ['PM', 'Consumer Staples', '0001413329'],
#  ['PSX', 'Energy', '0001534701'],
#  ['PNW', 'Utilities', '0000764622'],
#  ['PXD', 'Energy', '0001038357'],
#  ['PNC', 'Financials', '0000713676'],
#  ['POOL', 'Consumer Discretionary', '0000945841'],
#  ['PPG', 'Materials', '0000079879'],
#  ['PPL', 'Utilities', '0000922224'],
#  ['PFG', 'Financials', '0001126328'],
#  ['PG', 'Consumer Staples', '0000080424'],
#  ['PGR', 'Financials', '0000080661'],
#  ['PLD', 'Real Estate', '0001045609'],
#  ['PRU', 'Financials', '0001137774'],
#  ['PEG', 'Utilities', '0000788784'],
#  ['PTC', 'Information Technology', '0000857005'],
#  ['PSA', 'Real Estate', '0001393311'],
#  ['PHM', 'Consumer Discretionary', '0000822416'],
#  ['QRVO', 'Information Technology', '0001604778'],
#  ['PWR', 'Industrials', '0001050915'],
#  ['QCOM', 'Information Technology', '0000804328'],
#  ['DGX', 'Health Care', '0001022079'],
#  ['RL', 'Consumer Discretionary', '0001037038'],
#  ['RJF', 'Financials', '0000720005'],
#  ['RTX', 'Industrials', '0000101829'],
#  ['O', 'Real Estate', '0000726728'],
#  ['REG', 'Real Estate', '0000910606'],
#  ['REGN', 'Health Care', '0000872589'],
#  ['RF', 'Financials', '0001281761'],
#  ['RSG', 'Industrials', '0001060391'],
#  ['RMD', 'Health Care', '0000943819'],
#  ['RVTY', 'Health Care', '0000031791'],
#  ['RHI', 'Industrials', '0000315213'],
#  ['ROK', 'Industrials', '0001024478'],
#  ['ROL', 'Industrials', '0000084839'],
#  ['ROP', 'Information Technology', '0000882835'],
#  ['ROST', 'Consumer Discretionary', '0000745732'],
#  ['RCL', 'Consumer Discretionary', '0000884887'],
#  ['SPGI', 'Financials', '0000064040'],
#  ['CRM', 'Information Technology', '0001108524'],
#  ['SBAC', 'Real Estate', '0001034054'],
#  ['SLB', 'Energy', '0000087347'],
#  ['STX', 'Information Technology', '0001137789'],
#  ['SRE', 'Utilities', '0001032208'],
#  ['NOW', 'Information Technology', '0001373715'],
#  ['SHW', 'Materials', '0000089800'],
#  ['SPG', 'Real Estate', '0001063761'],
#  ['SWKS', 'Information Technology', '0000004127'],
#  ['SJM', 'Consumer Staples', '0000091419'],
#  ['SNA', 'Industrials', '0000091440'],
#  ['SO', 'Utilities', '0000092122'],
#  ['LUV', 'Industrials', '0000092380'],
#  ['SWK', 'Industrials', '0000093556'],
#  ['SBUX', 'Consumer Discretionary', '0000829224'],
#  ['STT', 'Financials', '0000093751'],
#  ['STLD', 'Materials', '0001022671'],
#  ['STE', 'Health Care', '0001757898'],
#  ['SYK', 'Health Care', '0000310764'],
#  ['SYF', 'Financials', '0001601712'],
#  ['SNPS', 'Information Technology', '0000883241'],
#  ['SYY', 'Consumer Staples', '0000096021'],
#  ['TMUS', 'Communication Services', '0001283699'],
#  ['TROW', 'Financials', '0001113169'],
#  ['TTWO', 'Communication Services', '0000946581'],
#  ['TPR', 'Consumer Discretionary', '0001116132'],
#  ['TRGP', 'Energy', '0001389170'],
#  ['TGT', 'Consumer Staples', '0000027419'],
#  ['TEL', 'Information Technology', '0001385157'],
#  ['TDY', 'Information Technology', '0001094285'],
#  ['TFX', 'Health Care', '0000096943'],
#  ['TER', 'Information Technology', '0000097210'],
#  ['TSLA', 'Consumer Discretionary', '0001318605'],
#  ['TXN', 'Information Technology', '0000097476'],
#  ['TXT', 'Industrials', '0000217346'],
#  ['TMO', 'Health Care', '0000097745'],
#  ['TJX', 'Consumer Discretionary', '0000109198'],
#  ['TSCO', 'Consumer Discretionary', '0000916365'],
#  ['TT', 'Industrials', '0001466258'],
#  ['TDG', 'Industrials', '0001260221'],
#  ['TRV', 'Financials', '0000086312'],
#  ['TRMB', 'Information Technology', '0000864749'],
#  ['TFC', 'Financials', '0000092230'],
#  ['TYL', 'Information Technology', '0000860731'],
#  ['TSN', 'Consumer Staples', '0000100493'],
#  ['USB', 'Financials', '0000036104'],
#  ['UBER', 'Industrials', '0001543151'],
#  ['UDR', 'Real Estate', '0000074208'],
#  ['ULTA', 'Consumer Discretionary', '0001403568'],
#  ['UNP', 'Industrials', '0000100885'],
#  ['UAL', 'Industrials', '0000100517'],
#  ['UPS', 'Industrials', '0001090727'],
#  ['URI', 'Industrials', '0001067701'],
#  ['UNH', 'Health Care', '0000731766'],
#  ['UHS', 'Health Care', '0000352915'],
#  ['VLO', 'Energy', '0001035002'],
#  ['VTR', 'Real Estate', '0000740260'],
#  ['VLTO', 'Industrials', '0001967680'],
#  ['VRSN', 'Information Technology', '0001014473'],
#  ['VRSK', 'Industrials', '0001442145'],
#  ['VZ', 'Communication Services', '0000732712'],
#  ['VRTX', 'Health Care', '0000875320'],
#  ['VFC', 'Consumer Discretionary', '0000103379'],
#  ['VTRS', 'Health Care', '0001792044'],
#  ['VICI', 'Real Estate', '0001705696'],
#  ['V', 'Financials', '0001403161'],
#  ['VMC', 'Materials', '0001396009'],
#  ['WRB', 'Financials', '0000011544'],
#  ['WAB', 'Industrials', '0000943452'],
#  ['WBA', 'Consumer Staples', '0001618921'],
#  ['WMT', 'Consumer Staples', '0000104169'],
#  ['DIS', 'Communication Services', '0001744489'],
#  ['WBD', 'Communication Services', '0001437107'],
#  ['WM', 'Industrials', '0000823768'],
#  ['WAT', 'Health Care', '0001000697'],
#  ['WEC', 'Utilities', '0000783325'],
#  ['WFC', 'Financials', '0000072971'],
#  ['WELL', 'Real Estate', '0000766704'],
#  ['WST', 'Health Care', '0000105770'],
#  ['WDC', 'Information Technology', '0000106040'],
#  ['WRK', 'Materials', '0001732845'],
#  ['WY', 'Real Estate', '0000106535'],
#  ['WHR', 'Consumer Discretionary', '0000106640'],
#  ['WMB', 'Energy', '0000107263'],
#  ['WTW', 'Financials', '0001140536'],
#  ['GWW', 'Industrials', '0000277135'],
#  ['WYNN', 'Consumer Discretionary', '0001174922'],
#  ['XEL', 'Utilities', '0000072903'],
#  ['XYL', 'Industrials', '0001524472'],
#  ['YUM', 'Consumer Discretionary', '0001041061'],
#  ['ZBRA', 'Information Technology', '0000877212'],
#  ['ZBH', 'Health Care', '0001136869'],
#  ['ZION', 'Financials', '0000109380'],
#  ['ZTS', 'Health Care', '0001555280']]

# %%
df.head()
# Out:
#   Symbol                  Sector
# 0    MMM             Industrials
# 1    AOS             Industrials
# 2    ABT             Health Care
# 3   ABBV             Health Care
# 4    ACN  Information Technology

# %%
import pandas as pd

df_info_tech = df[df['Sector'] == 'Information Technology'][['Symbol', 'CIK']]
symbols_list = df_info_tech['Symbol'].values.T.tolist()
cik_list = df_info_tech['CIK'].values.T.tolist()

# %%
import yfinance as yf

dates = [['2018-01-01', '2019-01-01'], ['2019-01-01', '2020-01-01'], ['2020-01-01', '2021-01-01'], ['2021-01-01', '2022-01-01'], ['2022-01-01', '2023-01-01'], ['2023-01-01', '2024-01-01']]

datas = []
for date in dates:
    data_df = pd.DataFrame(
    {'Date': [],
     'CIK': [],
     'Symbol': [],
     'Open': [],
     'High': [],
     'Low': [],
     'Close': [],
     'Volume': [],
     'Dividends': [],
     'Stock Splits': []
    })
    for i in range(len(symbols_list)):
        data = yf.Ticker(symbols_list[i]).history(period="1d", start=date[0], end=date[1])
        aux_df = pd.DataFrame(
            {'Date': data.index,
            'CIK': [cik_list[i]] * data.shape[0],
            'Symbol': [symbols_list[i]] * data.shape[0],
            'Open': data['Open'],
            'High': data['High'],
            'Low': data['Low'],
            'Close': data['Close'],
            'Volume': data['Volume'],
            'Dividends': data['Dividends'],
            'Stock Splits': data['Stock Splits']
            }
        )
        data_df = pd.concat([data_df, aux_df], ignore_index=True)
    datas.append(data_df)
# Out:
# C:\Users\mario\AppData\Local\Temp\ipykernel_8508\826691382.py:34: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   data_df = pd.concat([data_df, aux_df], ignore_index=True)
# C:\Users\mario\AppData\Local\Temp\ipykernel_8508\826691382.py:34: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   data_df = pd.concat([data_df, aux_df], ignore_index=True)
# C:\Users\mario\AppData\Local\Temp\ipykernel_8508\826691382.py:34: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   data_df = pd.concat([data_df, aux_df], ignore_index=True)
# C:\Users\mario\AppData\Local\Temp\ipykernel_8508\826691382.py:34: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   data_df = pd.concat([data_df, aux_df], ignore_index=True)
# C:\Users\mario\AppData\Local\Temp\ipykernel_8508\826691382.py:34: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   data_df = pd.concat([data_df, aux_df], ignore_index=True)
# C:\Users\mario\AppData\Local\Temp\ipykernel_8508\826691382.py:34: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   data_df = pd.concat([data_df, aux_df], ignore_index=True)

# %%
print(data_df)
# Out:
#                            Date         CIK Symbol        Open        High  \
# 0     2018-01-02 00:00:00-05:00  0001467373    ACN  140.065782  140.613276
# 1     2018-01-03 00:00:00-05:00  0001467373    ACN  139.600443  141.425404
# 2     2018-01-04 00:00:00-05:00  0001467373    ACN  141.434528  143.131743
# 3     2018-01-05 00:00:00-05:00  0001467373    ACN  142.903622  143.916476
# 4     2018-01-08 00:00:00-05:00  0001467373    ACN  143.597086  145.093554
# ...                         ...         ...    ...         ...         ...
# 16059 2018-12-24 00:00:00-05:00  0000877212   ZBRA  143.710007  148.220001
# 16060 2018-12-26 00:00:00-05:00  0000877212   ZBRA  145.070007  152.759995
# 16061 2018-12-27 00:00:00-05:00  0000877212   ZBRA  149.110001  155.360001
# 16062 2018-12-28 00:00:00-05:00  0000877212   ZBRA  156.979996  159.500000
# 16063 2018-12-31 00:00:00-05:00  0000877212   ZBRA  157.070007  159.330002
#
#               Low       Close     Volume  Dividends  Stock Splits
# 0      139.408795  140.376022  3061900.0        0.0           0.0
# 1      139.600443  141.023911  2064200.0        0.0           0.0
# 2      141.224661  142.693756  1777000.0        0.0           0.0
# 3      142.465635  143.870850  1597600.0        0.0           0.0
# 4      143.113472  145.020554  2616900.0        0.0           0.0
# ...           ...         ...        ...        ...           ...
# 16059  140.949997  142.899994   363000.0        0.0           0.0
# 16060  143.529999  152.520004   327200.0        0.0           0.0
# 16061  148.039993  155.350006   504500.0        0.0           0.0
# 16062  153.440002  155.970001   344800.0        0.0           0.0
# 16063  155.979996  159.229996   409100.0        0.0           0.0
#
# [16064 rows x 10 columns]

# %%
import fastavro
import pyorc
for i in range(len(datas)):
    datas[i]["Date"] = datas[i]["Date"].dt.tz_localize(None)
    datas[i]["CIK"] = datas[i]["CIK"].astype(int)
    
    # To csv
    datas[i].to_csv(f"data/data_year_{i+1}.csv")
    
    # To json
    datas[i].to_json(f"data/data_year_{i+1}.json")
    
    # To parquet
    datas[i].to_parquet(f"data/data_year_{i+1}.parquet", engine="pyarrow")
    
    # To excel
    datas[i].to_excel(f"data/data_year_{i+1}.xlsx")
    
    # To avro
    data_formatted = datas[i].copy()
    data_formatted["Date"] = data_formatted["Date"].astype(str)
    
    # Pass it to a dictionary to be able to write it to avro
    data_dict = data_formatted.to_dict(orient="records")
    avro_file_path = f"data/data_year_{i+1}.avro"
    orc_file_path = f"data/data_year_{i+1}.orc"
    schema = {
        "type": "record",
        "name": f"data_year_{i+1}",
        "fields": [
            {"name": "Date", "type": "string"},
            {"name": "CIK", "type": "int"},
            {"name": "Symbol", "type": "string"},
            {"name": "Open", "type": "double"},
            {"name": "High", "type": "double"},
            {"name": "Low", "type": "double"},
            {"name": "Close", "type": "double"},
            {"name": "Volume", "type": "double"},
            {"name": "Dividends", "type": "double"},
            {"name": "Stock Splits", "type": "double"}
        ]
    }
    
    # Write the avro file
    with open(avro_file_path, "wb") as f:
        fastavro.writer(f, schema, data_dict)
        
    # Write the orc schema
    orc_schema = "struct<Date:string,CIK:int,Symbol:string,Open:double,High:double,Low:double,Close:double,Volume:double,Dividends:double,StockSplits:double>"
    
    # Write the orc file
    with open(orc_file_path, "wb") as f2, open(avro_file_path, "rb") as f:
        reader = fastavro.reader(f)
        writer = pyorc.Writer(f2, orc_schema)
        
        for record in reader:
            # Writer.write() takes a tuple, but record is a dictionary, therefore we have to convert it to tuple
            writer.write(tuple(record.values()))
        
        writer.close()

# %%
# !pip install pyorc
# Out:
# Collecting pyorc
#   Obtaining dependency information for pyorc from https://files.pythonhosted.org/packages/81/60/502148946278db744f9e4aac408121aaa9deb09eab900f00aba25aff1072/pyorc-0.9.0-cp39-cp39-win_amd64.whl.metadata
#   Downloading pyorc-0.9.0-cp39-cp39-win_amd64.whl.metadata (2.9 kB)
# Requirement already satisfied: tzdata>=2020.5 in c:\users\mario\appdata\local\programs\python\python39\lib\site-packages (from pyorc) (2022.6)
# Downloading pyorc-0.9.0-cp39-cp39-win_amd64.whl (903 kB)
#    ---------------------------------------- 903.9/903.9 kB 6.3 MB/s eta 0:00:00
# Installing collected packages: pyorc
# Successfully installed pyorc-0.9.0
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
